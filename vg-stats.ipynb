# %% [markdown]
# # Video Game Sales

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Open And Print The .CSV File

# %%
vgsale = pd.read_csv('Game/vgsales.csv')
vgsale
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ## Which company is the most common video game publisher?

# %%
most_pub = vgsale['Publisher'].mode()
most_pub[0]
# Out:
# 'Electronic Arts'

# %% [markdown]
# ## What’s the most common platform?

# %%
most_com_plat = vgsale['Platform'].mode()
most_com_plat[0]
# Out:
# 'DS'

# %% [markdown]
# ## What about the most common genre?

# %%
most_com_gen = vgsale['Genre'].mode()
most_com_gen[0]
# Out:
# 'Action'

# %% [markdown]
# ## What are the top 20 highest grossing games?

# %%
top_20 = vgsale[['Name','Global_Sales','NA_Sales']].sort_values(by='Global_Sales',ascending=False).head(20)
top_20
# Out:
#                                             Name  Global_Sales  NA_Sales
# 0                                     Wii Sports         82.74     41.49
# 1                              Super Mario Bros.         40.24     29.08
# 2                                 Mario Kart Wii         35.82     15.85
# 3                              Wii Sports Resort         33.00     15.75
# 4                       Pokemon Red/Pokemon Blue         31.37     11.27
# 5                                         Tetris         30.26     23.20
# 6                          New Super Mario Bros.         30.01     11.38
# 7                                       Wii Play         29.02     14.03
# 8                      New Super Mario Bros. Wii         28.62     14.59
# 9                                      Duck Hunt         28.31     26.93
# 10                                    Nintendogs         24.76      9.07
# 11                                 Mario Kart DS         23.42      9.81
# ...

# %% [markdown]
# ## For North American video game sales, what’s the median?
# * Provide a secondary output showing ten games surrounding the median sales output.
#    * assume that games with same median value are sorted in descending order.

# %%
na_sales = vgsale['NA_Sales'].median()
na_sales
# x= vgsale[vgsale['Name']=='Spider-Man: Edge of Time']
# x
# Out:
# 0.08

# %%
median = vgsale[['NA_Sales']].median()[0]
result = vgsale[vgsale['NA_Sales']==median]
leng = len(result)
result = result[(leng//2)-5:(leng//2)+5]
result
# Out:
#         Rank                                Name Platform    Year  \
# 9931    9933            Spider-Man: Edge of Time      3DS  2011.0
# 9934    9936                    Turok: Evolution      GBA  2002.0
# 9957    9959                            Deadpool     XOne  2015.0
# 9996    9998          GT Advance 2: Rally Racing      GBA  2001.0
# 10000  10002                      A Witch's Tale       DS  2009.0
# 10012  10014                   Nickelodeon Dance     X360  2011.0
# 10020  10022            Phantasy Star Collection      GBA  2002.0
# 10022  10024               LEGO Knights' Kingdom      GBA  2004.0
# 10024  10026  Family Game Night 4: The Game Show      PS3  2011.0
# 10026  10028                        NBA Jam 2002      GBA  2002.0
#
#               Genre              Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 9931         Action             Activision      0.08      0.03      0.00
# 9934        Shooter  Acclaim Entertainment      0.08      0.03      0.00
# ...

# %% [markdown]
# ## For the top-selling game of all time, how many standard deviations above/below the mean are its sales for North America?

# %%
top_selling_game = top_20['NA_Sales'][0]
mean = vgsale['NA_Sales'].mean()
standard_deviation = vgsale['NA_Sales'].std()
result = (top_selling_game - mean) / standard_deviation
mean
top_selling_game
result
# Out:
# 50.47898767479108

# %% [markdown]
# ## The Nintendo Wii seems to have outdone itself with games. How does its average number of sales compare with all of the other platforms?

# %%
nintendo_average_sales = vgsale[vgsale['Platform']=='Wii']['Global_Sales'].mean()
other_platforms =  vgsale[vgsale['Platform'] != 'Wii']['Global_Sales'].mean()
nintendo_average_sales , other_platforms
# Out:
# (0.6994037735849057, 0.5233896418516336)

# %% [markdown]
# ## Sort The Platforms From Highest Average Sales.

# %%
highest_av_sl = vgsale.groupby('Platform').mean().sort_values('Global_Sales',ascending=False)['Global_Sales']
highest_av_sl
# Out:
# Platform
# GB      2.606633
# NES     2.561939
# GEN     1.050370
# SNES    0.837029
# PS4     0.827679
# X360    0.774672
# 2600    0.729925
# PS3     0.720722
# Wii     0.699404
# N64     0.686144
# XOne    0.662254
# PS      0.610920
# PS2     0.581046
# WiiU    0.572448
# 3DS     0.486169
# GBA     0.387470
# DS      0.380254
# GC      0.358561
# XB      0.313422
# SCD     0.311667
# DC      0.307115
# PC      0.269604
# PSP     0.244254
# WS      0.236667
# SAT     0.194162
# PSV     0.149952
# NG      0.120000
# TG16    0.080000
# GG      0.040000
# 3DO     0.033333
# PCFX    0.030000
# Name: Global_Sales, dtype: float64

# %% [markdown]
# ## Which game has the highest sales in EU?

# %%
highest_EU_sl = vgsale.sort_values('EU_Sales',ascending=False).head(1)
highest_EU_sl
# Out:
#    Rank        Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 0     1  Wii Sports      Wii  2006.0  Sports  Nintendo     41.49     29.02
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      3.77         8.46         82.74

# %% [markdown]
# ## Which game has the highest sales in JP?

# %%
highest_JP_sl = vgsale.sort_values('JP_Sales',ascending=False).head(1)
highest_JP_sl
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 4     11.27      8.89     10.22          1.0         31.37

# %%
def test():

    def assert_equal(actual,expected):
        assert actual == expected, f"Expected {expected} but got {actual}"

    assert_equal(most_pub[0], 'Electronic Arts')
    assert_equal(na_sales, 0.08)
    assert_equal(most_com_plat[0], 'DS')
    assert_equal(most_com_gen[0], 'Action')
    assert_equal(result, 50.47898767479108)
    assert_equal(other_platforms, 0.5233896418516336)
    assert_equal(nintendo_average_sales, 0.6994037735849057)

    print("Success!!!")

test()
# Out:
# Success!!!
